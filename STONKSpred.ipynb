# %% [markdown]
# <a href="https://colab.research.google.com/github/beetlegeusee/Machine_learning/blob/master/STONKSpred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# !pip install yfinance --upgrade --no-cache-dir
from pandas_datareader import data as pdr
import yfinance as yf
from collections import deque
import random
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.70-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 7.1 MB/s
# Collecting requests>=2.26
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 34.9 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Installing collected packages: requests, lxml, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed lxml-4.8.0 requests-2.27.1 yfinance-0.1.70

# %%
# !pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in /usr/local/lib/python3.7/dist-packages (0.9.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pandas_datareader) (4.8.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pandas_datareader) (2.27.1)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.7/dist-packages (from pandas_datareader) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas_datareader) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas_datareader) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas_datareader) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas_datareader) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas_datareader) (2.0.12)

# %%
yf.pdr_override()
df_full = pdr.get_data_yahoo("INFY", start="2018-01-01").reset_index()
df_full.to_csv('INFY.csv',index=False)
df_full.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Date   Open   High    Low  Close  Adj Close    Volume
# 0 2018-01-02  8.135  8.195  8.115  8.145   7.288744  12298200
# 1 2018-01-03  8.120  8.135  8.050  8.075   7.226102  10250800
# 2 2018-01-04  8.100  8.100  8.010  8.025   7.181358  16272000
# 3 2018-01-05  8.085  8.190  8.075  8.175   7.315591   9813600
# 4 2018-01-08  8.190  8.260  8.170  8.240   7.373756  11198200

# %%
df= df_full.copy()
name = 'Q-learning agent'
class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []
        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999
        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())
    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
# /usr/local/lib/python3.7/dist-packages/keras/legacy_tf_layers/core.py:261: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   return layer.apply(inputs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
# epoch: 10, total rewards: 19.404985.3, cost: 0.008553, total money: 10019.404985
# epoch: 20, total rewards: 20.959984.3, cost: 0.008347, total money: 10020.959984
# epoch: 30, total rewards: 20.344987.3, cost: 0.008286, total money: 10020.344987
# epoch: 40, total rewards: 26.824987.3, cost: 0.010814, total money: 10026.824987
# epoch: 50, total rewards: 26.554991.3, cost: 0.010255, total money: 10026.554991
# epoch: 60, total rewards: 24.289988.3, cost: 0.008273, total money: 10024.289988
# epoch: 70, total rewards: 18.364991.3, cost: 0.008288, total money: 10018.364991
# epoch: 80, total rewards: 17.354986.3, cost: 0.007966, total money: 10017.354986
# epoch: 90, total rewards: 13.384992.3, cost: 0.007912, total money: 10013.384992
# epoch: 100, total rewards: 15.649988.3, cost: 0.008287, total money: 10015.649988
# epoch: 110, total rewards: 14.699992.3, cost: 0.007815, total money: 10014.699992
# epoch: 120, total rewards: 16.204992.3, cost: 0.007769, total money: 10016.204992
# epoch: 130, total rewards: 12.734994.3, cost: 0.007719, total money: 10012.734994
# epoch: 140, total rewards: 15.049992.3, cost: 0.007675, total money: 10015.049992
# epoch: 150, total rewards: 13.609991.3, cost: 0.007127, total money: 10013.609991
# epoch: 160, total rewards: 23.569984.3, cost: 0.007594, total money: 10023.569984
# epoch: 170, total rewards: 14.579988.3, cost: 0.010496, total money: 10014.579988
# epoch: 180, total rewards: 17.369988.3, cost: 0.007499, total money: 10017.369988
# epoch: 190, total rewards: 11.459989.3, cost: 0.007449, total money: 10011.459989
# epoch: 200, total rewards: 13.069991.3, cost: 0.007408, total money: 10013.069991

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 10: buy 1 unit at price 9.060000, total balance 9990.940000
# day 11, sell 1 unit at price 8.960000, investment -1.103757 %, total balance 9999.900000,
# day 12: buy 1 unit at price 8.995000, total balance 9990.905000
# day 13, sell 1 unit at price 9.145000, investment 1.667599 %, total balance 10000.050000,
# day 15: buy 1 unit at price 9.230000, total balance 9990.820001
# day 16, sell 1 unit at price 9.225000, investment -0.054162 %, total balance 10000.045001,
# day 21: buy 1 unit at price 8.965000, total balance 9991.080001
# day 22, sell 1 unit at price 8.875000, investment -1.003906 %, total balance 9999.955001,
# day 23: buy 1 unit at price 8.685000, total balance 9991.270000
# day 24: buy 1 unit at price 8.735000, total balance 9982.535001
# day 25, sell 1 unit at price 8.740000, investment 0.633268 %, total balance 9991.275001,
# day 26: buy 1 unit at price 8.555000, total balance 9982.720000
# day 28: buy 1 unit at price 8.810000, total balance 9973.910000
# day 29, sell 1 unit at price 8.730000, investment -0.057242 %, total balance 9982.639999,
# day 30: buy 1 unit at price 8.785000, total balance 9973.855000
# day 31, sell 1 unit at price 8.805000, investment 2.922268 %, total balance 9982.660000,
# day 32, sell 1 unit at price 8.795000, investment -0.170265 %, total balance 9991.455000,
# day 33: buy 1 unit at price 8.820000, total balance 9982.635000
# day 34, sell 1 unit at price 8.835000, investment 0.569154 %, total balance 9991.470000,
# day 35, sell 1 unit at price 8.900000, investment 0.907029 %, total balance 10000.370000,
# day 37: buy 1 unit at price 8.840000, total balance 9991.530000
# day 38, sell 1 unit at price 8.760000, investment -0.904976 %, total balance 10000.290000,
# day 39: buy 1 unit at price 8.830000, total balance 9991.460000
# day 40, sell 1 unit at price 8.750000, investment -0.906001 %, total balance 10000.210000,
# day 41: buy 1 unit at price 8.875000, total balance 9991.335000
# day 42: buy 1 unit at price 9.000000, total balance 9982.335000
# day 43, sell 1 unit at price 8.995000, investment 1.352111 %, total balance 9991.330000,
# day 44: buy 1 unit at price 8.945000, total balance 9982.385000
# day 46, sell 1 unit at price 9.080000, investment 0.888888 %, total balance 9991.465000,
# day 47, sell 1 unit at price 9.205000, investment 2.906654 %, total balance 10000.670000,
# day 56: buy 1 unit at price 8.865000, total balance 9991.805000
# day 57, sell 1 unit at price 8.985000, investment 1.353637 %, total balance 10000.790000,
# day 58: buy 1 unit at price 8.860000, total balance 9991.930000
# day 59: buy 1 unit at price 8.845000, total balance 9983.085000
# day 60, sell 1 unit at price 8.925000, investment 0.733640 %, total balance 9992.010000,
# day 61: buy 1 unit at price 8.775000, total balance 9983.235001
# day 62: buy 1 unit at price 8.840000, total balance 9974.395000
# day 63, sell 1 unit at price 8.915000, investment 0.791404 %, total balance 9983.310000,
# day 64, sell 1 unit at price 8.935000, investment 1.823371 %, total balance 9992.245001,
# day 65, sell 1 unit at price 8.745000, investment -1.074664 %, total balance 10000.990001,
# day 68: buy 1 unit at price 8.675000, total balance 9992.315001
# day 71, sell 1 unit at price 8.495000, investment -2.074931 %, total balance 10000.810000,
# day 74: buy 1 unit at price 8.585000, total balance 9992.225000
# day 75, sell 1 unit at price 8.685000, investment 1.164827 %, total balance 10000.910001,
# day 86: buy 1 unit at price 8.720000, total balance 9992.190001
# day 87, sell 1 unit at price 8.660000, investment -0.688078 %, total balance 10000.850000,
# day 88: buy 1 unit at price 8.735000, total balance 9992.115001
# day 89, sell 1 unit at price 8.725000, investment -0.114474 %, total balance 10000.840001,
# day 91: buy 1 unit at price 8.825000, total balance 9992.015001
# day 92, sell 1 unit at price 8.760000, investment -0.736539 %, total balance 10000.775002,
# day 110: buy 1 unit at price 9.375000, total balance 9991.400002
# day 111, sell 1 unit at price 9.500000, investment 1.333333 %, total balance 10000.900002,
# day 116: buy 1 unit at price 9.100000, total balance 9991.800001
# day 117: buy 1 unit at price 9.080000, total balance 9982.720001
# day 118: buy 1 unit at price 9.115000, total balance 9973.605001
# day 119, sell 1 unit at price 9.360000, investment 2.857135 %, total balance 9982.965001,
# day 120, sell 1 unit at price 9.320000, investment 2.643169 %, total balance 9992.285001,
# day 121, sell 1 unit at price 9.360000, investment 2.687876 %, total balance 10001.645000,
# day 124: buy 1 unit at price 9.715000, total balance 9991.930000
# day 125, sell 1 unit at price 9.805000, investment 0.926404 %, total balance 10001.735001,
# day 131: buy 1 unit at price 9.880000, total balance 9991.855000
# day 132, sell 1 unit at price 10.005000, investment 1.265182 %, total balance 10001.860001,
# day 135: buy 1 unit at price 9.950000, total balance 9991.910001
# day 136: buy 1 unit at price 9.840000, total balance 9982.070001
# day 137, sell 1 unit at price 9.855000, investment -0.954777 %, total balance 9991.925000,
# day 138, sell 1 unit at price 10.005000, investment 1.676829 %, total balance 10001.930000,
# day 146: buy 1 unit at price 10.175000, total balance 9991.755000
# day 147, sell 1 unit at price 10.190000, investment 0.147414 %, total balance 10001.945000,
# day 149: buy 1 unit at price 10.295000, total balance 9991.650000
# day 150, sell 1 unit at price 10.300000, investment 0.048568 %, total balance 10001.950000,
# day 151: buy 1 unit at price 10.375000, total balance 9991.575000
# day 152: buy 1 unit at price 10.450000, total balance 9981.125000
# day 153, sell 1 unit at price 10.400000, investment 0.240960 %, total balance 9991.525000,
# day 154, sell 1 unit at price 10.410000, investment -0.382775 %, total balance 10001.934999,
# day 157: buy 1 unit at price 10.495000, total balance 9991.440000
# day 158, sell 1 unit at price 10.540000, investment 0.428776 %, total balance 10001.980000,
# day 162: buy 1 unit at price 10.190000, total balance 9991.790000
# day 163: buy 1 unit at price 10.150000, total balance 9981.640000
# day 164, sell 1 unit at price 10.270000, investment 0.785092 %, total balance 9991.910001,
# day 165: buy 1 unit at price 10.325000, total balance 9981.585001
# day 167, sell 1 unit at price 10.230000, investment 0.788177 %, total balance 9991.815001,
# day 168, sell 1 unit at price 10.385000, investment 0.581118 %, total balance 10002.200001,
# day 169: buy 1 unit at price 10.380000, total balance 9991.820001
# day 170, sell 1 unit at price 10.355000, investment -0.240853 %, total balance 10002.175000,
# day 182: buy 1 unit at price 9.930000, total balance 9992.245000
# day 183, sell 1 unit at price 9.950000, investment 0.201405 %, total balance 10002.195000,
# day 195: buy 1 unit at price 9.740000, total balance 9992.455000
# day 198: buy 1 unit at price 9.910000, total balance 9982.545000
# day 199, sell 1 unit at price 10.220000, investment 4.928137 %, total balance 9992.765000,
# day 200, sell 1 unit at price 9.800000, investment -1.109986 %, total balance 10002.565001,
# day 209: buy 1 unit at price 9.190000, total balance 9993.375001
# day 211: buy 1 unit at price 9.300000, total balance 9984.075001
# day 213, sell 1 unit at price 9.400000, investment 2.285093 %, total balance 9993.475000,
# day 214, sell 1 unit at price 9.480000, investment 1.935477 %, total balance 10002.955000,
# day 225: buy 1 unit at price 9.070000, total balance 9993.885000
# day 226, sell 1 unit at price 9.090000, investment 0.220512 %, total balance 10002.975000,
# day 230: buy 1 unit at price 9.680000, total balance 9993.295000
# day 231, sell 1 unit at price 9.860000, investment 1.859497 %, total balance 10003.155000,
# day 240: buy 1 unit at price 9.890000, total balance 9993.264999
# day 241: buy 1 unit at price 9.600000, total balance 9983.664999
# day 243: buy 1 unit at price 9.430000, total balance 9974.234999
# day 244, sell 1 unit at price 9.280000, investment -6.167852 %, total balance 9983.514998,
# day 245, sell 1 unit at price 9.100000, investment -5.208333 %, total balance 9992.614999,
# day 246: buy 1 unit at price 9.080000, total balance 9983.534999
# day 248, sell 1 unit at price 9.450000, investment 0.212084 %, total balance 9992.984999,
# day 251: buy 1 unit at price 9.610000, total balance 9983.374999
# day 252: buy 1 unit at price 9.470000, total balance 9973.904999
# day 253, sell 1 unit at price 9.630000, investment 6.057271 %, total balance 9983.534999,
# day 254, sell 1 unit at price 9.710000, investment 1.040587 %, total balance 9993.244999,
# day 255, sell 1 unit at price 9.750000, investment 2.956702 %, total balance 10002.994999,
# day 259: buy 1 unit at price 10.370000, total balance 9992.624999
# day 261, sell 1 unit at price 10.610000, investment 2.314366 %, total balance 10003.234999,
# day 265: buy 1 unit at price 10.530000, total balance 9992.704999
# day 266, sell 1 unit at price 10.430000, investment -0.949662 %, total balance 10003.134999,
# day 267: buy 1 unit at price 10.550000, total balance 9992.584999
# day 268, sell 1 unit at price 10.520000, investment -0.284358 %, total balance 10003.105000,
# day 272: buy 1 unit at price 10.900000, total balance 9992.205000
# day 273, sell 1 unit at price 10.870000, investment -0.275227 %, total balance 10003.075000,
# day 275: buy 1 unit at price 10.900000, total balance 9992.175000
# day 277, sell 1 unit at price 10.860000, investment -0.366972 %, total balance 10003.035000,
# day 278: buy 1 unit at price 10.820000, total balance 9992.215000
# day 279, sell 1 unit at price 10.770000, investment -0.462100 %, total balance 10002.985001,
# day 282: buy 1 unit at price 10.760000, total balance 9992.225000
# day 283: buy 1 unit at price 10.550000, total balance 9981.675000
# day 284: buy 1 unit at price 10.700000, total balance 9970.975000
# day 285: buy 1 unit at price 10.550000, total balance 9960.425000
# day 286: buy 1 unit at price 10.630000, total balance 9949.795000
# day 287, sell 1 unit at price 10.810000, investment 0.464686 %, total balance 9960.605000,
# day 288, sell 1 unit at price 10.730000, investment 1.706155 %, total balance 9971.335000,
# day 289: buy 1 unit at price 10.700000, total balance 9960.635000
# day 290, sell 1 unit at price 10.720000, investment 0.186920 %, total balance 9971.355000,
# day 292, sell 1 unit at price 10.720000, investment 1.611375 %, total balance 9982.075001,
# day 294, sell 1 unit at price 10.710000, investment 0.752586 %, total balance 9992.785001,
# day 297: buy 1 unit at price 10.550000, total balance 9982.235001
# day 298: buy 1 unit at price 10.520000, total balance 9971.715000
# day 299: buy 1 unit at price 10.550000, total balance 9961.165000
# day 300: buy 1 unit at price 10.600000, total balance 9950.565000
# day 301: buy 1 unit at price 10.700000, total balance 9939.865000
# day 303, sell 1 unit at price 10.900000, investment 1.869157 %, total balance 9950.764999,
# day 304, sell 1 unit at price 10.940000, investment 3.696677 %, total balance 9961.704999,
# day 305, sell 1 unit at price 11.060000, investment 5.133079 %, total balance 9972.764999,
# day 306, sell 1 unit at price 10.880000, investment 3.127961 %, total balance 9983.645000,
# day 308, sell 1 unit at price 10.820000, investment 2.075465 %, total balance 9994.464999,
# day 310: buy 1 unit at price 10.880000, total balance 9983.584999
# day 311, sell 1 unit at price 10.930000, investment 2.149537 %, total balance 9994.514999,
# day 312, sell 1 unit at price 11.090000, investment 1.930147 %, total balance 10005.605000,
# day 315: buy 1 unit at price 11.070000, total balance 9994.535000
# day 316, sell 1 unit at price 11.320000, investment 2.258356 %, total balance 10005.855000,
# day 319: buy 1 unit at price 11.080000, total balance 9994.775000
# day 320, sell 1 unit at price 10.970000, investment -0.992777 %, total balance 10005.745000,
# day 325: buy 1 unit at price 10.390000, total balance 9995.355000
# day 327: buy 1 unit at price 10.530000, total balance 9984.825000
# day 328, sell 1 unit at price 10.580000, investment 1.828677 %, total balance 9995.405000,
# day 329, sell 1 unit at price 10.520000, investment -0.094960 %, total balance 10005.925000,
# day 330: buy 1 unit at price 10.650000, total balance 9995.275001
# day 331, sell 1 unit at price 10.750000, investment 0.938971 %, total balance 10006.025001,
# day 336: buy 1 unit at price 10.450000, total balance 9995.575001
# day 337, sell 1 unit at price 10.340000, investment -1.052628 %, total balance 10005.915001,
# day 344: buy 1 unit at price 10.510000, total balance 9995.405001
# day 345, sell 1 unit at price 10.170000, investment -3.235016 %, total balance 10005.575001,
# day 353: buy 1 unit at price 10.570000, total balance 9995.005001
# day 354: buy 1 unit at price 10.470000, total balance 9984.535001
# day 355: buy 1 unit at price 10.450000, total balance 9974.085001
# day 357, sell 1 unit at price 10.440000, investment -1.229897 %, total balance 9984.525001,
# day 358: buy 1 unit at price 10.530000, total balance 9973.995001
# day 359, sell 1 unit at price 10.630000, investment 1.528174 %, total balance 9984.625001,
# day 360, sell 1 unit at price 10.780000, investment 3.157894 %, total balance 9995.405001,
# day 361: buy 1 unit at price 10.840000, total balance 9984.565001
# day 363, sell 1 unit at price 10.620000, investment 0.854702 %, total balance 9995.185000,
# day 365, sell 1 unit at price 10.600000, investment -2.214020 %, total balance 10005.785001,
# day 370: buy 1 unit at price 10.680000, total balance 9995.105000
# day 372, sell 1 unit at price 10.660000, investment -0.187270 %, total balance 10005.765000,
# day 378: buy 1 unit at price 10.690000, total balance 9995.075001
# day 380, sell 1 unit at price 10.420000, investment -2.525720 %, total balance 10005.495001,
# day 383: buy 1 unit at price 11.400000, total balance 9994.095001
# day 384, sell 1 unit at price 11.500000, investment 0.877196 %, total balance 10005.595001,
# day 386: buy 1 unit at price 11.490000, total balance 9994.105001
# day 388: buy 1 unit at price 11.390000, total balance 9982.715001
# day 389, sell 1 unit at price 11.460000, investment -0.261094 %, total balance 9994.175001,
# day 390, sell 1 unit at price 11.490000, investment 0.877958 %, total balance 10005.665001,
# day 393: buy 1 unit at price 11.480000, total balance 9994.185001
# day 394: buy 1 unit at price 11.510000, total balance 9982.675001
# day 395: buy 1 unit at price 11.420000, total balance 9971.255001
# day 396: buy 1 unit at price 11.320000, total balance 9959.935001
# day 397: buy 1 unit at price 11.260000, total balance 9948.675001
# day 398, sell 1 unit at price 11.080000, investment -3.484317 %, total balance 9959.755001,
# day 399: buy 1 unit at price 10.900000, total balance 9948.855001
# day 400: buy 1 unit at price 11.000000, total balance 9937.855001
# day 401, sell 1 unit at price 11.160000, investment -3.040837 %, total balance 9949.015001,
# day 402, sell 1 unit at price 11.250000, investment -1.488617 %, total balance 9960.265001,
# day 403: buy 1 unit at price 11.130000, total balance 9949.135001
# day 404, sell 1 unit at price 11.100000, investment -1.943457 %, total balance 9960.235002,
# day 407, sell 1 unit at price 10.930000, investment -2.930728 %, total balance 9971.165002,
# day 408, sell 1 unit at price 11.070000, investment 1.559634 %, total balance 9982.235002,
# day 411: buy 1 unit at price 11.300000, total balance 9970.935001
# day 412, sell 1 unit at price 11.210000, investment 1.909091 %, total balance 9982.145001,
# day 414, sell 1 unit at price 11.130000, investment 0.000000 %, total balance 9993.275002,
# day 415, sell 1 unit at price 11.150000, investment -1.327439 %, total balance 10004.425001,
# day 419: buy 1 unit at price 11.280000, total balance 9993.145001
# day 420, sell 1 unit at price 11.680000, investment 3.546104 %, total balance 10004.825002,
# day 421: buy 1 unit at price 12.070000, total balance 9992.755002
# day 422: buy 1 unit at price 11.810000, total balance 9980.945002
# day 423, sell 1 unit at price 11.640000, investment -3.562546 %, total balance 9992.585002,
# day 424, sell 1 unit at price 11.620000, investment -1.608811 %, total balance 10004.205002,
# day 427: buy 1 unit at price 11.770000, total balance 9992.435001
# day 428, sell 1 unit at price 11.760000, investment -0.084964 %, total balance 10004.195002,
# day 429: buy 1 unit at price 11.670000, total balance 9992.525002
# day 431: buy 1 unit at price 11.600000, total balance 9980.925001
# day 432: buy 1 unit at price 11.350000, total balance 9969.575001
# day 433, sell 1 unit at price 11.000000, investment -5.741217 %, total balance 9980.575001,
# day 434, sell 1 unit at price 11.040000, investment -4.827590 %, total balance 9991.615001,
# day 435: buy 1 unit at price 11.060000, total balance 9980.555000
# day 436, sell 1 unit at price 11.130000, investment -1.938328 %, total balance 9991.685000,
# day 437: buy 1 unit at price 11.210000, total balance 9980.475000
# day 441: buy 1 unit at price 11.160000, total balance 9969.315001
# day 442, sell 1 unit at price 11.220000, investment 1.446653 %, total balance 9980.535001,
# day 443, sell 1 unit at price 11.290000, investment 0.713648 %, total balance 9991.825001,
# day 444, sell 1 unit at price 11.120000, investment -0.358423 %, total balance 10002.945001,
# day 448: buy 1 unit at price 10.620000, total balance 9992.325001
# day 449: buy 1 unit at price 10.670000, total balance 9981.655001
# day 451, sell 1 unit at price 10.590000, investment -0.282483 %, total balance 9992.245001,
# day 452: buy 1 unit at price 10.570000, total balance 9981.675001
# day 455, sell 1 unit at price 9.040000, investment -15.276477 %, total balance 9990.715001,
# day 457, sell 1 unit at price 9.200000, investment -12.961210 %, total balance 9999.915001,
# day 460: buy 1 unit at price 9.320000, total balance 9990.595001
# day 462, sell 1 unit at price 9.520000, investment 2.145931 %, total balance 10000.115002,
# day 466: buy 1 unit at price 10.020000, total balance 9990.095001
# day 469: buy 1 unit at price 9.750000, total balance 9980.345001
# day 471, sell 1 unit at price 9.870000, investment -1.497012 %, total balance 9990.215001,
# day 473, sell 1 unit at price 9.860000, investment 1.128202 %, total balance 10000.075001,
# day 483: buy 1 unit at price 9.670000, total balance 9990.405001
# day 484, sell 1 unit at price 9.860000, investment 1.964835 %, total balance 10000.265000,
# day 485: buy 1 unit at price 9.890000, total balance 9990.375000
# day 486, sell 1 unit at price 9.940000, investment 0.505553 %, total balance 10000.315000,
# day 487: buy 1 unit at price 9.940000, total balance 9990.375000
# day 488, sell 1 unit at price 10.040000, investment 1.006040 %, total balance 10000.415000,
# day 495: buy 1 unit at price 10.270000, total balance 9990.145000
# day 496, sell 1 unit at price 10.290000, investment 0.194737 %, total balance 10000.434999,
# day 498: buy 1 unit at price 10.240000, total balance 9990.195000
# day 499, sell 1 unit at price 10.170000, investment -0.683591 %, total balance 10000.365000,
# day 503: buy 1 unit at price 10.290000, total balance 9990.075000
# day 504, sell 1 unit at price 10.310000, investment 0.194368 %, total balance 10000.385000,
# day 508: buy 1 unit at price 10.480000, total balance 9989.905001
# day 509, sell 1 unit at price 10.650000, investment 1.622138 %, total balance 10000.555000,
# day 519: buy 1 unit at price 10.990000, total balance 9989.565001
# day 520: buy 1 unit at price 11.100000, total balance 9978.465000
# day 521, sell 1 unit at price 11.060000, investment 0.636949 %, total balance 9989.525001,
# day 522: buy 1 unit at price 11.060000, total balance 9978.465000
# day 523, sell 1 unit at price 10.960000, investment -1.261264 %, total balance 9989.425000,
# day 524, sell 1 unit at price 10.940000, investment -1.084999 %, total balance 10000.365000,
# day 528: buy 1 unit at price 10.850000, total balance 9989.514999
# day 529, sell 1 unit at price 10.920000, investment 0.645158 %, total balance 10000.434999,
# day 530: buy 1 unit at price 10.950000, total balance 9989.485000
# day 531: buy 1 unit at price 11.220000, total balance 9978.264999
# day 532, sell 1 unit at price 11.100000, investment 1.369868 %, total balance 9989.365000,
# day 533, sell 1 unit at price 11.010000, investment -1.871658 %, total balance 10000.375000,
# day 535: buy 1 unit at price 11.300000, total balance 9989.075000
# day 536: buy 1 unit at price 11.360000, total balance 9977.715000
# day 537, sell 1 unit at price 11.410000, investment 0.973448 %, total balance 9989.125000,
# day 538, sell 1 unit at price 11.220000, investment -1.232389 %, total balance 10000.345000,
# day 545: buy 1 unit at price 10.470000, total balance 9989.875000
# day 546: buy 1 unit at price 10.130000, total balance 9979.745000
# day 547, sell 1 unit at price 9.780000, investment -6.590263 %, total balance 9989.525000,
# day 550, sell 1 unit at price 8.900000, investment -12.142157 %, total balance 9998.424999,
# day 554: buy 1 unit at price 7.870000, total balance 9990.554999
# day 555: buy 1 unit at price 7.350000, total balance 9983.204999
# day 557: buy 1 unit at price 6.940000, total balance 9976.264999
# day 558, sell 1 unit at price 7.120000, investment -9.529860 %, total balance 9983.384999,
# day 560: buy 1 unit at price 8.190000, total balance 9975.195000
# day 564, sell 1 unit at price 8.210000, investment 11.700682 %, total balance 9983.405000,
# day 566, sell 1 unit at price 7.910000, investment 13.976942 %, total balance 9991.315000,
# day 569: buy 1 unit at price 8.380000, total balance 9982.934999
# day 571, sell 1 unit at price 8.520000, investment 4.029315 %, total balance 9991.455000,
# day 572, sell 1 unit at price 8.500000, investment 1.431980 %, total balance 9999.955000,
# day 578: buy 1 unit at price 8.250000, total balance 9991.705000
# day 581, sell 1 unit at price 8.760000, investment 6.181821 %, total balance 10000.465000,
# day 585: buy 1 unit at price 9.230000, total balance 9991.235001
# day 586, sell 1 unit at price 9.060000, investment -1.841811 %, total balance 10000.295001,
# day 587: buy 1 unit at price 8.930000, total balance 9991.365001
# day 588: buy 1 unit at price 8.910000, total balance 9982.455001
# day 590, sell 1 unit at price 9.040000, investment 1.231799 %, total balance 9991.495001,
# day 592, sell 1 unit at price 9.000000, investment 1.010103 %, total balance 10000.495001,
# day 596: buy 1 unit at price 8.700000, total balance 9991.795001
# day 597, sell 1 unit at price 8.960000, investment 2.988508 %, total balance 10000.755001,
# day 598: buy 1 unit at price 8.790000, total balance 9991.965001
# day 599, sell 1 unit at price 9.000000, investment 2.389079 %, total balance 10000.965001,
# day 600: buy 1 unit at price 8.930000, total balance 9992.035001
# day 601: buy 1 unit at price 9.050000, total balance 9982.985001
# day 603, sell 1 unit at price 9.350000, investment 4.703248 %, total balance 9992.335001,
# day 604: buy 1 unit at price 9.190000, total balance 9983.145001
# day 605, sell 1 unit at price 9.100000, investment 0.552488 %, total balance 9992.245002,
# day 606, sell 1 unit at price 9.260000, investment 0.761705 %, total balance 10001.505002,
# day 607: buy 1 unit at price 9.380000, total balance 9992.125002
# day 608: buy 1 unit at price 9.270000, total balance 9982.855001
# day 609, sell 1 unit at price 9.270000, investment -1.172704 %, total balance 9992.125002,
# day 610: buy 1 unit at price 9.380000, total balance 9982.745002
# day 611, sell 1 unit at price 9.560000, investment 3.128371 %, total balance 9992.305002,
# day 612: buy 1 unit at price 9.330000, total balance 9982.975002
# day 613, sell 1 unit at price 9.300000, investment -0.852878 %, total balance 9992.275002,
# day 614: buy 1 unit at price 8.860000, total balance 9983.415003
# day 615, sell 1 unit at price 9.110000, investment -2.357988 %, total balance 9992.525002,
# day 616: buy 1 unit at price 9.220000, total balance 9983.305002
# day 617: buy 1 unit at price 9.120000, total balance 9974.185002
# day 618: buy 1 unit at price 9.330000, total balance 9964.855002
# day 620: buy 1 unit at price 9.160000, total balance 9955.695003
# day 621: buy 1 unit at price 9.150000, total balance 9946.545003
# day 622, sell 1 unit at price 9.420000, investment 6.320547 %, total balance 9955.965003,
# day 623, sell 1 unit at price 9.070000, investment -1.626904 %, total balance 9965.035003,
# day 624, sell 1 unit at price 9.290000, investment 1.864036 %, total balance 9974.325003,
# day 626, sell 1 unit at price 9.570000, investment 2.572345 %, total balance 9983.895002,
# day 627: buy 1 unit at price 9.660000, total balance 9974.235003
# day 628, sell 1 unit at price 9.680000, investment 5.676861 %, total balance 9983.915003,
# day 630: buy 1 unit at price 10.110000, total balance 9973.805003
# day 631, sell 1 unit at price 10.240000, investment 11.912570 %, total balance 9984.045003,
# day 632, sell 1 unit at price 10.340000, investment 7.039341 %, total balance 9994.385003,
# day 633: buy 1 unit at price 10.230000, total balance 9984.155004
# day 634, sell 1 unit at price 10.390000, investment 2.769542 %, total balance 9994.545004,
# day 635: buy 1 unit at price 10.470000, total balance 9984.075004
# day 637, sell 1 unit at price 11.910000, investment 16.422291 %, total balance 9995.985003,
# day 638: buy 1 unit at price 12.230000, total balance 9983.755004
# day 639, sell 1 unit at price 12.270000, investment 17.191978 %, total balance 9996.025004,
# day 640, sell 1 unit at price 12.580000, investment 2.861818 %, total balance 10008.605004,
# day 642: buy 1 unit at price 12.300000, total balance 9996.305004
# day 643, sell 1 unit at price 12.240000, investment -0.487808 %, total balance 10008.545004,
# day 646: buy 1 unit at price 12.580000, total balance 9995.965004
# day 647, sell 1 unit at price 12.850000, investment 2.146268 %, total balance 10008.815004,
# day 648: buy 1 unit at price 12.950000, total balance 9995.865005
# day 649: buy 1 unit at price 12.850000, total balance 9983.015004
# day 650, sell 1 unit at price 12.920000, investment -0.231658 %, total balance 9995.935004,
# day 651: buy 1 unit at price 12.640000, total balance 9983.295004
# day 652: buy 1 unit at price 12.650000, total balance 9970.645004
# day 653, sell 1 unit at price 12.830000, investment -0.155646 %, total balance 9983.475004,
# day 654: buy 1 unit at price 12.600000, total balance 9970.875004
# day 655, sell 1 unit at price 12.590000, investment -0.395571 %, total balance 9983.465004,
# day 656: buy 1 unit at price 12.630000, total balance 9970.835004
# day 657: buy 1 unit at price 12.760000, total balance 9958.075004
# day 659: buy 1 unit at price 12.720000, total balance 9945.355003
# day 660, sell 1 unit at price 12.870000, investment 1.739133 %, total balance 9958.225003,
# day 661: buy 1 unit at price 12.980000, total balance 9945.245004
# day 662, sell 1 unit at price 12.800000, investment 1.587300 %, total balance 9958.045004,
# day 663, sell 1 unit at price 12.820000, investment 1.504351 %, total balance 9970.865004,
# day 664: buy 1 unit at price 12.600000, total balance 9958.265003
# day 665: buy 1 unit at price 12.790000, total balance 9945.475003
# day 666: buy 1 unit at price 12.810000, total balance 9932.665003
# day 667: buy 1 unit at price 12.880000, total balance 9919.785003
# day 668, sell 1 unit at price 12.780000, investment 0.156736 %, total balance 9932.565002,
# day 669, sell 1 unit at price 12.810000, investment 0.707548 %, total balance 9945.375003,
# day 672: buy 1 unit at price 12.730000, total balance 9932.645003
# day 674, sell 1 unit at price 12.440000, investment -4.160246 %, total balance 9945.085003,
# day 675: buy 1 unit at price 12.670000, total balance 9932.415003
# day 676, sell 1 unit at price 12.750000, investment 1.190473 %, total balance 9945.165003,
# day 677, sell 1 unit at price 12.600000, investment -1.485532 %, total balance 9957.765003,
# day 678, sell 1 unit at price 12.760000, investment -0.390322 %, total balance 9970.525003,
# day 679, sell 1 unit at price 13.240000, investment 2.795028 %, total balance 9983.765003,
# day 680: buy 1 unit at price 13.340000, total balance 9970.425003
# day 681, sell 1 unit at price 13.560000, investment 6.520039 %, total balance 9983.985003,
# day 682, sell 1 unit at price 13.670000, investment 7.892660 %, total balance 9997.655004,
# day 683, sell 1 unit at price 13.500000, investment 1.199399 %, total balance 10011.155004,
# day 684: buy 1 unit at price 13.610000, total balance 9997.545004
# day 685, sell 1 unit at price 13.840000, investment 1.689938 %, total balance 10011.385004,
# day 689: buy 1 unit at price 13.630000, total balance 9997.755004
# day 690, sell 1 unit at price 13.560000, investment -0.513571 %, total balance 10011.315004,
# day 693: buy 1 unit at price 13.670000, total balance 9997.645004
# day 694, sell 1 unit at price 14.050000, investment 2.779811 %, total balance 10011.695004,
# day 695: buy 1 unit at price 13.890000, total balance 9997.805004
# day 696, sell 1 unit at price 14.540000, investment 4.679623 %, total balance 10012.345004,
# day 699: buy 1 unit at price 15.550000, total balance 9996.795004
# day 700, sell 1 unit at price 15.720000, investment 1.093248 %, total balance 10012.515004,
# day 702: buy 1 unit at price 15.260000, total balance 9997.255004
# day 703, sell 1 unit at price 15.510000, investment 1.638270 %, total balance 10012.765004,
# day 705: buy 1 unit at price 15.370000, total balance 9997.395004
# day 706: buy 1 unit at price 15.340000, total balance 9982.055004
# day 707, sell 1 unit at price 15.350000, investment -0.130120 %, total balance 9997.405005,
# day 708: buy 1 unit at price 15.220000, total balance 9982.185004
# day 709, sell 1 unit at price 14.920000, investment -2.737940 %, total balance 9997.105004,
# day 711: buy 1 unit at price 14.380000, total balance 9982.725004
# day 712: buy 1 unit at price 14.280000, total balance 9968.445004
# day 713, sell 1 unit at price 14.270000, investment -6.241786 %, total balance 9982.715005,
# day 714, sell 1 unit at price 14.250000, investment -0.904034 %, total balance 9996.965005,
# day 715: buy 1 unit at price 14.300000, total balance 9982.665005
# day 716: buy 1 unit at price 14.680000, total balance 9967.985004
# day 718: buy 1 unit at price 14.930000, total balance 9953.055004
# day 720, sell 1 unit at price 14.540000, investment 1.820730 %, total balance 9967.595004,
# day 721, sell 1 unit at price 15.090000, investment 5.524475 %, total balance 9982.685004,
# day 722: buy 1 unit at price 14.950000, total balance 9967.735004
# day 723, sell 1 unit at price 15.290000, investment 4.155311 %, total balance 9983.025004,
# day 724: buy 1 unit at price 15.460000, total balance 9967.565004
# day 725: buy 1 unit at price 15.280000, total balance 9952.285005
# day 727: buy 1 unit at price 14.830000, total balance 9937.455005
# day 728, sell 1 unit at price 14.910000, investment -0.133962 %, total balance 9952.365005,
# day 729, sell 1 unit at price 15.380000, investment 2.876256 %, total balance 9967.745005,
# day 730, sell 1 unit at price 15.530000, investment 0.452779 %, total balance 9983.275004,
# day 731, sell 1 unit at price 15.100000, investment -1.178006 %, total balance 9998.375005,
# day 732, sell 1 unit at price 14.920000, investment 0.606879 %, total balance 10013.295005,
# day 733: buy 1 unit at price 15.220000, total balance 9998.075005
# day 734, sell 1 unit at price 15.380000, investment 1.051247 %, total balance 10013.455005,
# day 735: buy 1 unit at price 15.410000, total balance 9998.045005
# day 736, sell 1 unit at price 15.240000, investment -1.103180 %, total balance 10013.285005,
# day 738: buy 1 unit at price 15.620000, total balance 9997.665005
# day 740: buy 1 unit at price 15.530000, total balance 9982.135005
# day 741, sell 1 unit at price 15.500000, investment -0.768245 %, total balance 9997.635005,
# day 743: buy 1 unit at price 15.660000, total balance 9981.975005
# day 744: buy 1 unit at price 15.610000, total balance 9966.365005
# day 745, sell 1 unit at price 15.660000, investment 0.837090 %, total balance 9982.025005,
# day 746, sell 1 unit at price 16.209999, investment 3.512128 %, total balance 9998.235004,
# day 747: buy 1 unit at price 16.219999, total balance 9982.015005
# day 749, sell 1 unit at price 16.580000, investment 6.213967 %, total balance 9998.595005,
# day 750, sell 1 unit at price 16.590000, investment 2.281140 %, total balance 10015.185005,
# day 751: buy 1 unit at price 16.600000, total balance 9998.585005
# day 752, sell 1 unit at price 16.770000, investment 1.024097 %, total balance 10015.355005,
# day 756: buy 1 unit at price 17.250000, total balance 9998.105005
# day 757, sell 1 unit at price 17.650000, investment 2.318838 %, total balance 10015.755005,
# day 761: buy 1 unit at price 18.760000, total balance 9996.995005
# day 762, sell 1 unit at price 18.600000, investment -0.852878 %, total balance 10015.595005,
# day 763: buy 1 unit at price 18.430000, total balance 9997.165005
# day 764, sell 1 unit at price 18.219999, investment -1.139452 %, total balance 10015.385004,
# day 766: buy 1 unit at price 18.120001, total balance 9997.265003
# day 767, sell 1 unit at price 18.400000, investment 1.545247 %, total balance 10015.665003,
# day 769: buy 1 unit at price 18.180000, total balance 9997.485003
# day 771: buy 1 unit at price 17.850000, total balance 9979.635002
# day 772: buy 1 unit at price 17.469999, total balance 9962.165003
# day 773, sell 1 unit at price 17.639999, investment -2.970302 %, total balance 9979.805002,
# day 774: buy 1 unit at price 16.879999, total balance 9962.925003
# day 775: buy 1 unit at price 17.379999, total balance 9945.545004
# day 776, sell 1 unit at price 17.440001, investment -2.296918 %, total balance 9962.985004,
# day 777: buy 1 unit at price 17.650000, total balance 9945.335005
# day 778: buy 1 unit at price 17.590000, total balance 9927.745005
# day 779, sell 1 unit at price 17.629999, investment 0.915855 %, total balance 9945.375004,
# day 781, sell 1 unit at price 17.639999, investment 4.502371 %, total balance 9963.015003,
# day 782, sell 1 unit at price 17.500000, investment 0.690454 %, total balance 9980.515003,
# day 783, sell 1 unit at price 17.830000, investment 1.019832 %, total balance 9998.345003,
# day 784: buy 1 unit at price 18.070000, total balance 9980.275003
# day 785: buy 1 unit at price 17.750000, total balance 9962.525003
# day 786, sell 1 unit at price 17.600000, investment 0.056852 %, total balance 9980.125004,
# day 787, sell 1 unit at price 17.830000, investment -1.328167 %, total balance 9997.955004,
# day 790, sell 1 unit at price 17.379999, investment -2.084512 %, total balance 10015.335003,
# day 794: buy 1 unit at price 17.660000, total balance 9997.675003
# day 795: buy 1 unit at price 18.020000, total balance 9979.655003
# day 796, sell 1 unit at price 18.459999, investment 4.530007 %, total balance 9998.115002,
# day 797: buy 1 unit at price 18.170000, total balance 9979.945002
# day 799, sell 1 unit at price 17.980000, investment -0.221981 %, total balance 9997.925001,
# day 800, sell 1 unit at price 18.600000, investment 2.366540 %, total balance 10016.525002,
# day 803: buy 1 unit at price 18.910000, total balance 9997.615002
# day 804, sell 1 unit at price 19.150000, investment 1.269169 %, total balance 10016.765001,
# day 806: buy 1 unit at price 19.100000, total balance 9997.665001
# day 807: buy 1 unit at price 18.379999, total balance 9979.285002
# day 808, sell 1 unit at price 18.750000, investment -1.832463 %, total balance 9998.035002,
# day 810, sell 1 unit at price 18.709999, investment 1.795429 %, total balance 10016.745001,
# day 811: buy 1 unit at price 18.660000, total balance 9998.085001
# day 812, sell 1 unit at price 18.459999, investment -1.071815 %, total balance 10016.545000,
# day 814: buy 1 unit at price 18.430000, total balance 9998.115000
# day 815: buy 1 unit at price 18.799999, total balance 9979.315001
# day 816, sell 1 unit at price 18.719999, investment 1.573516 %, total balance 9998.035000,
# day 817, sell 1 unit at price 19.010000, investment 1.117027 %, total balance 10017.045000,
# day 819: buy 1 unit at price 19.340000, total balance 9997.705000
# day 820, sell 1 unit at price 19.209999, investment -0.672188 %, total balance 10016.914999,
# day 822: buy 1 unit at price 19.540001, total balance 9997.374998
# day 823: buy 1 unit at price 19.120001, total balance 9978.254997
# day 824, sell 1 unit at price 18.410000, investment -5.783014 %, total balance 9996.664997,
# day 825, sell 1 unit at price 17.309999, investment -9.466534 %, total balance 10013.974997,
# day 827: buy 1 unit at price 18.180000, total balance 9995.794996
# day 828: buy 1 unit at price 18.260000, total balance 9977.534996
# day 829: buy 1 unit at price 18.030001, total balance 9959.504995
# day 830, sell 1 unit at price 18.100000, investment -0.440044 %, total balance 9977.604996,
# day 832: buy 1 unit at price 17.889999, total balance 9959.714996
# day 833, sell 1 unit at price 18.010000, investment -1.369113 %, total balance 9977.724997,
# day 834, sell 1 unit at price 18.110001, investment 0.443704 %, total balance 9995.834997,
# day 837: buy 1 unit at price 18.080000, total balance 9977.754997
# day 838, sell 1 unit at price 18.200001, investment 1.732819 %, total balance 9995.954998,
# day 840, sell 1 unit at price 18.290001, investment 1.161510 %, total balance 10014.244999,
# day 841: buy 1 unit at price 18.600000, total balance 9995.644999
# day 842, sell 1 unit at price 18.379999, investment -1.182802 %, total balance 10014.024998,
# day 845: buy 1 unit at price 17.840000, total balance 9996.184998
# day 846: buy 1 unit at price 17.879999, total balance 9978.304998
# day 847: buy 1 unit at price 18.160000, total balance 9960.144999
# day 848, sell 1 unit at price 18.170000, investment 1.849775 %, total balance 9978.314999,
# day 849, sell 1 unit at price 18.260000, investment 2.125286 %, total balance 9996.574999,
# day 851, sell 1 unit at price 18.650000, investment 2.698237 %, total balance 10015.224998,
# day 855: buy 1 unit at price 19.260000, total balance 9995.964998
# day 856, sell 1 unit at price 19.370001, investment 0.571135 %, total balance 10015.334999,
# day 858: buy 1 unit at price 19.270000, total balance 9996.064999
# day 860: buy 1 unit at price 19.139999, total balance 9976.924999
# day 862, sell 1 unit at price 19.400000, investment 0.674619 %, total balance 9996.324999,
# day 863, sell 1 unit at price 19.500000, investment 1.880881 %, total balance 10015.824999,
# day 866: buy 1 unit at price 20.540001, total balance 9995.284998
# day 867, sell 1 unit at price 20.450001, investment -0.438170 %, total balance 10015.734999,
# day 875: buy 1 unit at price 21.190001, total balance 9994.544998
# day 876, sell 1 unit at price 21.250000, investment 0.283150 %, total balance 10015.794998,
# day 878: buy 1 unit at price 21.450001, total balance 9994.344997
# day 880, sell 1 unit at price 20.959999, investment -2.284390 %, total balance 10015.304996,
# day 883: buy 1 unit at price 21.180000, total balance 9994.124996
# day 884: buy 1 unit at price 20.950001, total balance 9973.174995
# day 885, sell 1 unit at price 21.340000, investment 0.755429 %, total balance 9994.514996,
# day 886: buy 1 unit at price 21.049999, total balance 9973.464996
# day 887: buy 1 unit at price 21.049999, total balance 9952.414997
# day 888, sell 1 unit at price 21.389999, investment 2.100232 %, total balance 9973.804996,
# day 889: buy 1 unit at price 21.129999, total balance 9952.674997
# day 890: buy 1 unit at price 20.860001, total balance 9931.814997
# day 891, sell 1 unit at price 20.639999, investment -1.947743 %, total balance 9952.454996,
# day 892: buy 1 unit at price 20.940001, total balance 9931.514996
# day 893, sell 1 unit at price 21.309999, investment 1.235156 %, total balance 9952.824995,
# day 894, sell 1 unit at price 21.330000, investment 0.946525 %, total balance 9974.154995,
# day 895, sell 1 unit at price 21.730000, investment 4.170656 %, total balance 9995.884995,
# day 896, sell 1 unit at price 21.709999, investment 3.677166 %, total balance 10017.594994,
# day 903: buy 1 unit at price 22.639999, total balance 9994.954994
# day 904, sell 1 unit at price 22.580000, investment -0.265015 %, total balance 10017.534994,
# day 905: buy 1 unit at price 22.809999, total balance 9994.724995
# day 907: buy 1 unit at price 22.780001, total balance 9971.944994
# day 908, sell 1 unit at price 22.990000, investment 0.789129 %, total balance 9994.934994,
# day 909, sell 1 unit at price 23.320000, investment 2.370496 %, total balance 10018.254993,
# day 910: buy 1 unit at price 23.629999, total balance 9994.624994
# day 912, sell 1 unit at price 23.559999, investment -0.296232 %, total balance 10018.184994,
# day 916: buy 1 unit at price 24.100000, total balance 9994.084993
# day 917, sell 1 unit at price 23.879999, investment -0.912868 %, total balance 10017.964993,
# day 919: buy 1 unit at price 23.660000, total balance 9994.304993
# day 920: buy 1 unit at price 23.730000, total balance 9970.574993
# day 921: buy 1 unit at price 23.719999, total balance 9946.854994
# day 922: buy 1 unit at price 23.820000, total balance 9923.034994
# day 923: buy 1 unit at price 23.549999, total balance 9899.484995
# day 924, sell 1 unit at price 23.700001, investment 0.169066 %, total balance 9923.184996,
# day 925: buy 1 unit at price 24.030001, total balance 9899.154995
# day 926: buy 1 unit at price 23.430000, total balance 9875.724995
# day 927: buy 1 unit at price 23.190001, total balance 9852.534994
# day 928, sell 1 unit at price 22.930000, investment -3.371257 %, total balance 9875.464994,
# day 929: buy 1 unit at price 22.990000, total balance 9852.474995
# day 931, sell 1 unit at price 23.010000, investment -2.993251 %, total balance 9875.484995,
# day 932: buy 1 unit at price 23.370001, total balance 9852.114994
# day 935: buy 1 unit at price 22.760000, total balance 9829.354994
# day 937, sell 1 unit at price 23.270000, investment -2.308981 %, total balance 9852.624994,
# day 938, sell 1 unit at price 23.730000, investment 0.764333 %, total balance 9876.354994,
# day 939: buy 1 unit at price 23.680000, total balance 9852.674994
# day 940, sell 1 unit at price 22.900000, investment -4.702460 %, total balance 9875.574993,
# day 942, sell 1 unit at price 22.480000, investment -4.054634 %, total balance 9898.054993,
# day 943, sell 1 unit at price 22.250000, investment -4.053474 %, total balance 9920.304993,
# day 944: buy 1 unit at price 22.330000, total balance 9897.974993
# day 945, sell 1 unit at price 22.150000, investment -3.653763 %, total balance 9920.124992,
# day 946, sell 1 unit at price 22.750000, investment -2.652977 %, total balance 9942.874992,
# day 949: buy 1 unit at price 21.930000, total balance 9920.944992
# day 952, sell 1 unit at price 22.650000, investment -0.483307 %, total balance 9943.594992,
# day 953: buy 1 unit at price 22.709999, total balance 9920.884993
# day 954, sell 1 unit at price 23.379999, investment -1.266897 %, total balance 9944.264992,
# day 958, sell 1 unit at price 23.410000, investment 4.836542 %, total balance 9967.674992,
# day 959, sell 1 unit at price 23.010000, investment 4.924760 %, total balance 9990.684992,
# day 960, sell 1 unit at price 22.930000, investment 0.968742 %, total balance 10013.614992,
# day 963: buy 1 unit at price 22.559999, total balance 9991.054993
# day 964: buy 1 unit at price 22.280001, total balance 9968.774992
# day 965: buy 1 unit at price 22.469999, total balance 9946.304993
# day 966: buy 1 unit at price 22.660000, total balance 9923.644993
# day 967, sell 1 unit at price 22.709999, investment 0.664892 %, total balance 9946.354992,
# day 968, sell 1 unit at price 22.709999, investment 1.929975 %, total balance 9969.064991,
# day 969, sell 1 unit at price 22.790001, investment 1.424128 %, total balance 9991.854992,
# day 970: buy 1 unit at price 23.440001, total balance 9968.414991
# day 971, sell 1 unit at price 23.299999, investment 2.824357 %, total balance 9991.714991,
# day 972, sell 1 unit at price 22.959999, investment -2.047788 %, total balance 10014.674990,
# day 980: buy 1 unit at price 22.770000, total balance 9991.904989
# day 981, sell 1 unit at price 22.889999, investment 0.527005 %, total balance 10014.794989,
# day 982: buy 1 unit at price 22.610001, total balance 9992.184988
# day 984: buy 1 unit at price 22.620001, total balance 9969.564987
# day 985, sell 1 unit at price 22.580000, investment -0.132688 %, total balance 9992.144987,
# day 986, sell 1 unit at price 22.440001, investment -0.795757 %, total balance 10014.584988,
# day 987: buy 1 unit at price 23.440001, total balance 9991.144987
# day 989, sell 1 unit at price 22.250000, investment -5.076794 %, total balance 10013.394987,
# day 990: buy 1 unit at price 23.059999, total balance 9990.334988
# day 991, sell 1 unit at price 23.440001, investment 1.647880 %, total balance 10013.774988,
# day 993: buy 1 unit at price 23.190001, total balance 9990.584988
# day 994, sell 1 unit at price 22.610001, investment -2.501078 %, total balance 10013.194988,
# day 998: buy 1 unit at price 24.040001, total balance 9989.154987
# day 1001: buy 1 unit at price 24.530001, total balance 9964.624987
# day 1002: buy 1 unit at price 24.730000, total balance 9939.894987
# day 1003, sell 1 unit at price 25.330000, investment 5.366052 %, total balance 9965.224987,
# day 1004: buy 1 unit at price 25.299999, total balance 9939.924988
# day 1006, sell 1 unit at price 25.410000, investment 3.587440 %, total balance 9965.334988,
# day 1007: buy 1 unit at price 25.309999, total balance 9940.024988
# day 1008, sell 1 unit at price 25.260000, investment 2.143149 %, total balance 9965.284988,
# day 1009, sell 1 unit at price 25.110001, investment -0.750983 %, total balance 9990.394989,
# day 1012, sell 1 unit at price 24.200001, investment -4.385613 %, total balance 10014.594990,
# day 1014: buy 1 unit at price 25.020000, total balance 9989.574989
# day 1015: buy 1 unit at price 25.750000, total balance 9963.824989
# day 1016, sell 1 unit at price 25.600000, investment 2.318145 %, total balance 9989.424990,
# day 1017: buy 1 unit at price 26.200001, total balance 9963.224989
# day 1018, sell 1 unit at price 25.510000, investment -0.932038 %, total balance 9988.734989,
# day 1019, sell 1 unit at price 24.469999, investment -6.603059 %, total balance 10013.204988,
# day 1023: buy 1 unit at price 22.480000, total balance 9990.724989
# day 1026: buy 1 unit at price 22.660000, total balance 9968.064989
# day 1027: buy 1 unit at price 23.570000, total balance 9944.494989
# day 1028: buy 1 unit at price 23.520000, total balance 9920.974989
# day 1029: buy 1 unit at price 23.770000, total balance 9897.204988
# day 1030, sell 1 unit at price 22.760000, investment 1.245555 %, total balance 9919.964989,
# day 1032, sell 1 unit at price 22.469999, investment -0.838484 %, total balance 9942.434988,
# day 1033, sell 1 unit at price 22.889999, investment -2.885025 %, total balance 9965.324987,
# day 1034, sell 1 unit at price 23.410000, investment -0.467690 %, total balance 9988.734987,
# day 1038: buy 1 unit at price 22.889999, total balance 9965.844988
# day 1039: buy 1 unit at price 22.840000, total balance 9943.004988
# day 1040: buy 1 unit at price 22.430000, total balance 9920.574987
# day 1041: buy 1 unit at price 22.510000, total balance 9898.064987
# day 1042, sell 1 unit at price 23.049999, investment -3.029033 %, total balance 9921.114986,
# day 1043: buy 1 unit at price 22.719999, total balance 9898.394987
# day 1044: buy 1 unit at price 22.240000, total balance 9876.154987
# day 1045, sell 1 unit at price 22.840000, investment -0.218433 %, total balance 9898.994987,
# day 1046, sell 1 unit at price 22.459999, investment -1.663752 %, total balance 9921.454987,
# day 1048, sell 1 unit at price 22.590000, investment 0.713330 %, total balance 9944.044987,
# day 1049, sell 1 unit at price 22.520000, investment 0.044426 %, total balance 9966.564987,
# day 1050, sell 1 unit at price 22.459999, investment -1.144367 %, total balance 9989.024986,
# day 1053: buy 1 unit at price 23.900000, total balance 9965.124987
# day 1055, sell 1 unit at price 24.010000, investment 7.958635 %, total balance 9989.134987,
# day 1056, sell 1 unit at price 24.690001, investment 3.305443 %, total balance 10013.824987,
# day 1061: buy 1 unit at price 24.209999, total balance 9989.614988
# day 1062: buy 1 unit at price 24.790001, total balance 9964.824987
# day 1063, sell 1 unit at price 24.309999, investment 0.413054 %, total balance 9989.134987,
# day 1064, sell 1 unit at price 24.670000, investment -0.484070 %, total balance 10013.804987,
# day 1065: buy 1 unit at price 24.730000, total balance 9989.074987
# day 1066, sell 1 unit at price 24.719999, investment -0.040438 %, total balance 10013.794987,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()
